# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
with open("data/processed/train_sample.csv", "r") as f:
    df = pd.read_csv(f)
    f.close()

df.head()
# Out:
#        ip  app  device  os  channel           click_time attributed_time  \
# 0   87540   12       1  13      497  2017-11-07 09:30:38             NaN
# 1  105560   25       1  17      259  2017-11-07 13:40:27             NaN
# 2  101424   12       1  19      212  2017-11-07 18:05:24             NaN
# 3   94584   13       1  13      477  2017-11-07 04:58:08             NaN
# 4   68413   12       1   1      178  2017-11-09 09:00:09             NaN
#
#    is_attributed
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df.groupby('is_attributed').describe().stack()
# Out:
#                               app       channel        device             ip  \
# is_attributed
# 0             count  99773.000000  99773.000000  99773.000000   99773.000000
#               mean      12.001964    268.976857     21.779860   91072.821575
#               std       14.840636    129.715348    259.928394   69624.459455
#               min        1.000000      3.000000      0.000000       9.000000
#               25%        3.000000    145.000000      1.000000   40462.000000
#               50%       12.000000    258.000000      1.000000   79800.000000
#               75%       15.000000    379.000000      1.000000  118154.000000
#               max      551.000000    498.000000   3867.000000  364757.000000
# 1             count    227.000000    227.000000    227.000000     227.000000
#               mean      32.229075    205.365639     17.986784  171715.154185
#               std       33.769395    117.758991     89.035564  106667.455804
# ...
